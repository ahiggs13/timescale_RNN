# %%
import os
import glob

# %%
configs_dir = 'configs/debugging/'

with open("test.txt", "w") as f:
    for config in os.listdir(configs_dir):
        print(f'python -u run_expt.py --config=configs/debugging/{config} --seed=0 --name={config.split('.yaml')[0]}', file=f)
